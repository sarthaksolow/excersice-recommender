# %%
! pip install -q --upgrade google-generativeai langchain-google-genai chromadb pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 41.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.7/427.7 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.4 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
from IPython.display import display
from IPython.display import Markdown
import textwrap
import langchain_google_genai
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import google.generativeai as genai
from google.colab import userdata
import os

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm=ChatGoogleGenerativeAI(model="gemini-pro",google_api_key=GOOGLE_API_KEY)

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
def exercise(age, weight, goal, profession):

    message = HumanMessage(
        content= f"The user is a {age}-year-old {profession} weighing {weight} kg. Their goal is {goal}. "
                    "Please provide a personalized at home exercise plan consisting of basic workouts according to the age for a week so that they could follow and target diff sections of body each day to ensure good physical fitness."
    )


    response = llm.invoke([message])

    print(response.content)

# Example usage
exercise(age=30, weight=70, goal="loose weight", profession="homemaker")
# Out:
# **Personalized Home Exercise Plan for a 30-Year-Old Homemaker**
#
# **Goal:** Weight loss
#
# **Day 1: Upper Body**
#
# * **Push-ups:** 3 sets of 10 reps
# * **Triceps dips (using a chair):** 3 sets of 15 reps
# * **Shoulder presses (using dumbbells or water bottles):** 3 sets of 12 reps
# * **Bicep curls (using dumbbells or resistance bands):** 3 sets of 15 reps
#
# **Day 2: Lower Body**
#
# * **Squats:** 3 sets of 20 reps
# * **Lunges:** 3 sets of 15 reps per leg
# * **Calf raises:** 3 sets of 25 reps
# * **Glute bridges:** 3 sets of 20 reps
#
# **Day 3: Core**
#
# * **Plank:** 3 sets of 30-60 seconds hold
# * **Side plank:** 3 sets of 30-60 seconds hold per side
# * **Russian twists:** 3 sets of 20 reps
# * **Leg raises:** 3 sets of 15 reps
#
# **Day 4: Rest**
#
# **Day 5: Full Body**
#
# * **Jumping jacks:** 3 sets of 50 reps
# * **Burpees:** 3 sets of 10 reps
# * **Mountain climbers:** 3 sets of 30 seconds
# * **High knees:** 3 sets of 30 seconds
#
# **Day 6: Upper Body**
#
# * **Push-ups with knee modification:** 3 sets of 12 reps
# * **Incline push-ups (using a wall or furniture):** 3 sets of 15 reps
# * **Triceps dips:** 3 sets of 18 reps
# * **Shoulder flyes (using dumbbells or resistance bands):** 3 sets of 12 reps
#
# **Day 7: Lower Body**
#
# * **Squats with calf raises:** 3 sets of 15 reps
# * **Lunges with overhead press:** 3 sets of 12 reps per leg
# * **Single-leg deadlifts:** 3 sets of 15 reps per leg
# * **Hamstring curls:** 3 sets of 15 reps
#
# **Tips:**
#
# * Warm up for 5-10 minutes before each workout.
# * Cool down for 5-10 minutes after each workout.
# * Listen to your body and rest when needed.
# * Gradually increase the intensity and duration of your workouts as you get stronger.
# * Combine this exercise plan with a healthy diet for optimal weight loss results.
